# %%
from Algorithm import Algorithm
from PulseSequence import PulseSequence
from Pulse import Pulse
from HamiltonianOperator import *
from Gate import *

import numpy as np
import matplotlib.pyplot as plt

# %%
ta_00 = Algorithm("TA|00>")
ta_00\
    .state_prep("00")\


plt.figure(figsize=(10,10))
ta_00.execute_algorithm()

# %%
ta_01 = Algorithm("TA|01>")
ta_01\
    .state_prep("01")\


plt.figure(figsize=(10,10))
ta_01.execute_algorithm()

# %%
ta_10 = Algorithm("TA|10>")
ta_10\
    .state_prep("10")\


plt.figure(figsize=(10,10))
ta_10.execute_algorithm()

# %%
ta_11 = Algorithm("TA|11>")
ta_11\
    .state_prep("11")\


plt.figure(figsize=(10,10))
ta_11.print_sequences()
ta_11.execute_algorithm()
# Out:
#  TA|11> P0 Pulse Sequence:
#
# TA|11> P1 Pulse Sequence: Sx(+pi/2) -> 2IzSz(aka delay(1/2J)) -> Sy(+pi/2) -> Ix(+pi/2) -> 2IzSz(aka delay(1/2J)) -> Iy(+pi/2)
#
# TA|11> P2 Pulse Sequence: Ix(+pi/2) -> 2IzSz(aka delay(1/2J)) -> Sx(+pi/2) -> Iy(+pi/2) -> 2IzSz(aka delay(1/2J)) -> Sy(+pi/2)
