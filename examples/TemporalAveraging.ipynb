# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../src'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from simulator.Algorithm import Algorithm
from simulator.PulseSequence import PulseSequence
from simulator.Pulse import Pulse
from simulator.HamiltonianOperator import *
from simulator.Gate import *

import numpy as np
import matplotlib.pyplot as plt

# %%
ta_00 = Algorithm("TA|00>")
ta_00\
    .state_prep("00")\

ta_00.print_sequences()
plt.figure(figsize=(10,10))
ta_00.execute_algorithm(invert_x=False)
# Out:
#  TA|00> P0 Pulse Sequence: Ix(pi) -> Sx(pi)
#
# TA|00> P1 Pulse Sequence: Sx(+pi/2) -> 2IzSz(aka delay(1/2J)) -> Sy(+pi/2) -> Ix(+pi/2) -> 2IzSz(aka delay(1/2J)) -> Iy(+pi/2) -> Ix(pi) -> Sx(pi)
#
# TA|00> P2 Pulse Sequence: Ix(+pi/2) -> 2IzSz(aka delay(1/2J)) -> Sx(+pi/2) -> Iy(+pi/2) -> 2IzSz(aka delay(1/2J)) -> Sy(+pi/2) -> Ix(pi) -> Sx(pi)

# %%
ta_01 = Algorithm("TA|01>")
ta_01\
    .state_prep("01")\


plt.figure(figsize=(10,10))

ta_01.print_sequences()
ta_01.execute_algorithm(invert_x=False)
# Out:
#  TA|01> P0 Pulse Sequence: Ix(pi)
#
# TA|01> P1 Pulse Sequence: Sx(+pi/2) -> 2IzSz(aka delay(1/2J)) -> Sy(+pi/2) -> Ix(+pi/2) -> 2IzSz(aka delay(1/2J)) -> Iy(+pi/2) -> Ix(pi)
#
# TA|01> P2 Pulse Sequence: Ix(+pi/2) -> 2IzSz(aka delay(1/2J)) -> Sx(+pi/2) -> Iy(+pi/2) -> 2IzSz(aka delay(1/2J)) -> Sy(+pi/2) -> Ix(pi)

# %%
ta_10 = Algorithm("TA|10>")
ta_10\
    .state_prep("10")\


plt.figure(figsize=(10,10))
ta_10.print_sequences()
ta_10.execute_algorithm(invert_x=False)
# Out:
#  TA|10> P0 Pulse Sequence: Sx(pi)
#
# TA|10> P1 Pulse Sequence: Sx(+pi/2) -> 2IzSz(aka delay(1/2J)) -> Sy(+pi/2) -> Ix(+pi/2) -> 2IzSz(aka delay(1/2J)) -> Iy(+pi/2) -> Sx(pi)
#
# TA|10> P2 Pulse Sequence: Ix(+pi/2) -> 2IzSz(aka delay(1/2J)) -> Sx(+pi/2) -> Iy(+pi/2) -> 2IzSz(aka delay(1/2J)) -> Sy(+pi/2) -> Sx(pi)

# %%
ta_11 = Algorithm("TA|11>")
ta_11\
    .state_prep("11")\


plt.figure(figsize=(10,10))
ta_11.print_sequences()
ta_11.execute_algorithm(invert_x=False)
# Out:
#  TA|11> P0 Pulse Sequence:
#
# TA|11> P1 Pulse Sequence: Sx(+pi/2) -> 2IzSz(aka delay(1/2J)) -> Sy(+pi/2) -> Ix(+pi/2) -> 2IzSz(aka delay(1/2J)) -> Iy(+pi/2)
#
# TA|11> P2 Pulse Sequence: Ix(+pi/2) -> 2IzSz(aka delay(1/2J)) -> Sx(+pi/2) -> Iy(+pi/2) -> 2IzSz(aka delay(1/2J)) -> Sy(+pi/2)
