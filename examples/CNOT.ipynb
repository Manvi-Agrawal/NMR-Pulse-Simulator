# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../src'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from simulator.Algorithm import Algorithm
from simulator.PulseSequence import PulseSequence
from simulator.Pulse import Pulse
from simulator.HamiltonianOperator import *
from simulator.Gate import *

import numpy as np
import matplotlib.pyplot as plt

from matplotlib.gridspec import GridSpec
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from simulator.Algorithm import Algorithm
#       2 from simulator.PulseSequence import PulseSequence
#       3 from simulator.Pulse import Pulse
#
# ModuleNotFoundError: No module named 'simulator'

# %%
cnot_00 = Algorithm("CNOT|00>")
cnot_00\
    .state_prep("00")\
    .add_sequence(cx)\


plt.figure(figsize=(10,10))
cnot_00.execute_algorithm(invert_x=False)

# %%
cnot_01 = Algorithm("CNOT|01>")
cnot_01\
    .state_prep("01")\
    .add_sequence(cx)\


plt.figure(figsize=(10,10))
cnot_01.execute_algorithm(invert_x=False)

# %%
cnot_10 = Algorithm("CNOT|10>")
cnot_10\
    .state_prep("10")\
    .add_sequence(cx)\


plt.figure(figsize=(10,10))
cnot_10.execute_algorithm(invert_x=False)

# %%
cnot_11 = Algorithm("CNOT|11>")
cnot_11\
    .state_prep("11")\
    .add_sequence(cx)\


plt.figure(figsize=(12,10))
cnot_11.execute_algorithm(invert_x=False)
