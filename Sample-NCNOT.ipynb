# %%
from Algorithm import Algorithm
from PulseSequence import PulseSequence
from HamiltonianOperator import *
from Gate import *

# %%
near_cnot_00 = Algorithm("NEAR CNOT|00>")
near_cnot_00\
    .state_prep("00")\
    .add_sequence(ncx)\


near_cnot_00.execute_algorithm()

# %%
near_cnot_01 = Algorithm("NEAR CNOT|01>")
near_cnot_01\
    .state_prep("01")\
    .add_sequence(ncx)\

near_cnot_01.execute_algorithm()

# %%
near_cnot_10 = Algorithm("NEAR CNOT|10>")
near_cnot_10\
    .state_prep("10")\
    .add_sequence(ncx)\


near_cnot_10.execute_algorithm()

# %%
near_cnot_11 = Algorithm("Near CNOT|11>")
near_cnot_11\
    .state_prep("11")\
    .add_sequence(ncx)\

near_cnot_11.execute_algorithm()
